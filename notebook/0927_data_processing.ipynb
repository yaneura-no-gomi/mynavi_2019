# %%
import sys
import os
import glob
import re

import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
df = pd.read_csv('../processed_data/train.csv')

# %%
116/12
# Out:
# 9.666666666666666

# %%
df.head()
# Out:
#    id       y           location  \
# 0   1   75000        東京都北区滝野川３丁目
# 1   2   76000        東京都中央区月島３丁目
# 2   3  110000        東京都渋谷区笹塚２丁目
# 3   4  150000  東京都杉並区高円寺南２丁目23-2
# 4   5   74000     東京都葛飾区金町３丁目7-2
#
#                                               access layout      age  \
# 0  都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...     1K    9年9ヶ月
# 1  都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...     1R  44年10ヶ月
# 2  京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...     1K    8年6ヶ月
# 3  総武線・中央線（各停）\t高円寺駅\t徒歩9分\t\t丸ノ内線(池袋－荻窪)\t新高円寺駅\...   2LDK   29年4ヶ月
# 4  京成金町線\t京成金町駅\t徒歩5分\t\t常磐線\t金町(東京都)駅\t徒歩7分\t\t京...    2DK   31年7ヶ月
#
#   direction     area     floor  \
# 0        南東  20.01m2   1階／12階建
# 1       NaN   16.5m2   5階／10階建
# 2         南  22.05m2  12階／15階建
# 3         南  60.48m2    3階／4階建
# 4         南  39.66m2    1階／2階建
#
#                                          bath_toilet  \
# 0   専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座
# ...

# %%
df.to_csv('../processed_data/train_v2.csv',index=False)
df = pd.read_csv('../processed_data/train_v2.csv')

# %%
df.head()
# Out:
#    id       y           location  \
# 0   1   75000        東京都北区滝野川３丁目
# 1   2   76000        東京都中央区月島３丁目
# 2   3  110000        東京都渋谷区笹塚２丁目
# 3   4  150000  東京都杉並区高円寺南２丁目23-2
# 4   5   74000     東京都葛飾区金町３丁目7-2
#
#                                               access layout      age  \
# 0  都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...     1K    9年9ヶ月
# 1  都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...     1R  44年10ヶ月
# 2  京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...     1K    8年6ヶ月
# 3  総武線・中央線（各停）\t高円寺駅\t徒歩9分\t\t丸ノ内線(池袋－荻窪)\t新高円寺駅\...   2LDK   29年4ヶ月
# 4  京成金町線\t京成金町駅\t徒歩5分\t\t常磐線\t金町(東京都)駅\t徒歩7分\t\t京...    2DK   31年7ヶ月
#
#   direction     area     floor  \
# 0        南東  20.01m2   1階／12階建
# 1       NaN   16.5m2   5階／10階建
# 2         南  22.05m2  12階／15階建
# 3         南  60.48m2    3階／4階建
# 4         南  39.66m2    1階／2階建
#
#                                          bath_toilet  \
# 0   専用バス／\t専用トイレ／\tバス・トイレ別／\tシャワー／\t浴室乾燥機\t／\t温水洗浄便座
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# id                   0
# y                    0
# location             0
# access               0
# layout               0
# age                  0
# direction         2749
# area                 0
# floor                0
# bath_toilet        329
# kitchen            621
# broadcast_com     3440
# facilities          82
# parking           5287
# enviroment        9432
# structure            0
# contact_period    7120
# max_floor            0
# dtype: int64

# %% [markdown]
# ## layout の前処理

# %%
df['layout'].unique()
# Out:
# array(['1K', '1R', '2LDK', '2DK', '1DK', '1LDK', '3LDK', '3DK',
#        '1LDK+S(納戸)', '4K', '2K', '1K+S(納戸)', '4LDK', '3LDK+S(納戸)',
#        '5LDK+S(納戸)', '5LDK', '3K', '4DK', '2LDK+S(納戸)', '2DK+S(納戸)',
#        '4LDK+S(納戸)', '5DK', '3DK+S(納戸)', '1DK+S(納戸)', '5K', '6LDK',
#        '2K+S(納戸)', '1LK+S(納戸)', '5DK+S(納戸)', '3K+S(納戸)'], dtype=object)

# %% [markdown]
# - 一文字目から部屋数を取得

# %%
room_num = [s[0] for s in df['layout']]

# %%
'K' in df.loc[0,'layout']
# Out:
# True

# %%
def layout_split(layout):
    room_num = []
    l,d,k,s = [],[],[],[]
    
    for v in layout:
        room_num.append(int(v[0]))
        
        for x, r_type in zip([l,d,k,s],['L','D','K','S']):
            
            if r_type in v:
                x.append(1)
                
            else :
                x.append(0)
        
    return room_num,l,d,k,s

# %%
room_num,l,d,k,s = layout_split(df['layout'])

# %%
lay_out = pd.DataFrame({
    'id': df['id'],
    'room_num': room_num,
    'L': l,
    'D': d,
    'K': k,
    'S': s
})

# %%
room_num.index(6)
# Out:
# 13411

# %%
lay_out.to_csv('../processed_data/layout_v1.csv')

# %%
df.columns
# Out:
# Index(['id', 'y', 'location', 'access', 'layout', 'age', 'direction', 'area',
#        'floor', 'bath_toilet', 'kitchen', 'broadcast_com', 'facilities',
#        'parking', 'enviroment', 'structure', 'contact_period'],
#       dtype='object')

# %% [markdown]
# ### direction についての前処理

# %% [markdown]
# - 北向きは家賃が下がるらしいので、北向きの場合にフラグ
# - 欠損は「不明」として一時的に対応

# %%
df['direction'].value_counts()
# Out:
# 南     8909
# 東     4995
# 西     4026
# 南東    3098
# 南西    3080
# 北     1966
# 北西    1326
# 北東    1321
# Name: direction, dtype: int64

# %%
df['direction'].isnull().sum()
# Out:
# 2749

# %%
def north_flag(direction):
    res = []
    
    direction = direction.fillna('')
    
    for d in direction:
        if  '北' in d:
            res.append(1)
        
        else:
            res.append(0)
            
    return res

# %%
n_flag = north_flag(df['direction'])

# %%
n_flag = pd.DataFrame({
    'id': df['id'],
    'north': n_flag,
})

# %%
n_flag.to_csv('../processed_data/north_flag.csv',index=False)

# %%
n_flag
# Out:
#           id  north
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 31465  31466      0
# 31466  31467      0
# 31467  31468      0
# 31468  31469      0
# 31469  31470      0
#
# [31470 rows x 2 columns]

# %%
pd.read_csv('../processed_data/train_v2.csv')
# Out:
#        Unnamed: 0     id       y           location  \
# 0               0      1   75000        東京都北区滝野川３丁目
# 1               1      2   76000        東京都中央区月島３丁目
# 2               2      3  110000        東京都渋谷区笹塚２丁目
# 3               3      4  150000  東京都杉並区高円寺南２丁目23-2
# 4               4      5   74000     東京都葛飾区金町３丁目7-2
# ...           ...    ...     ...                ...
# 31465       31465  31466   80000        東京都板橋区蓮根２丁目
# 31466       31466  31467   54500  東京都世田谷区太子堂５丁目17-1
# 31467       31467  31468  125000        東京都江東区南砂４丁目
# 31468       31468  31469   98000        東京都中野区中野２丁目
# 31469       31469  31470   81000        東京都豊島区千川２丁目
#
#                                                   access layout  age  \
# 0      都営三田線\t西巣鴨駅\t徒歩4分\t\t埼京線\t板橋駅\t徒歩14分\t\t都電荒川線\...     1K  117
# 1      都営大江戸線\t勝どき駅\t徒歩5分\t\t有楽町線\t月島駅\t徒歩9分\t\t日比谷線\...     1R  538
# 2      京王線\t笹塚駅\t徒歩6分\t\t京王線\t代田橋駅\t徒歩7分\t\t京王線\t明大前駅...     1K  102
# ...

# %%
df = pd.read_csv('../processed_data/train_v1.csv')
# merge lay_out
df = pd.merge(df,lay_out,on='id')
df = pd.merge(df,n_flag,on='id')
df.head()
# Out:
#    id  age   area  floor  max_floor       y  room_num  L  D  K  S  north
# 0   1  117  20.01      1         12   75000         1  0  0  1  0      0
# 1   2  538  16.50      5         10   76000         1  0  0  0  0      0
# 2   3  102  22.05     12         15  110000         1  0  0  1  0      0
# 3   4  352  60.48      3          4  150000         2  1  1  1  0      0
# 4   5  379  39.66      1          2   74000         2  0  1  1  0      0

# %%
df.to_csv('../processed_data/train_v3.csv',index=False)
